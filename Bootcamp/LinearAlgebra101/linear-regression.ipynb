# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
x_train = np.array([1.0, 2.0, 3.0, 5.3, 6.6, 6.7, 9.0])
y_train = np.array([200, 250,300, 460, 5.30, 5.40, 720])

# %%
m = x_train.shape[0]
print(m)
# Out:
# 7

# %%
i = 0
x_i = x_train[i]
print(x_i)
y_i = y_train[i]
print(y_i)
# Out:
# 1.0
# 200.0

# %%
plt.scatter(x_train, y_train, marker='x', c='r')
plt.title("Housing Prices")
plt.ylabel('Price (in 1000s of dollars)')
plt.xlabel('Size (1000 sqft)')
plt.show()
